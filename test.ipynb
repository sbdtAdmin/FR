# %%
import cv2 as cv
import face_recognition
import os
import pickle

# %%
database = {}

# Загрузка базы данных сотрудников
def saveDBS(database):
    import face_recognition
    import os, pickle
    for filename in os.listdir('database'):
        if filename.endswith('.jpg'):
            name = os.path.splitext(filename)[0]
            img = face_recognition.load_image_file(os.path.join('database', filename))
            encodings = face_recognition.face_encodings(img)[0]
            database[name] = encodings
    pickle.dump(database, open('database.pkl', 'wb'))
    return pickle.load(open('database.pkl', 'rb'))

database = saveDBS(database)

print(database)
# Out:
# {'320961766': array([-0.07665486,  0.10211027,  0.07425506, -0.08457673, -0.0750073 ,
#         0.01161012, -0.00712613,  0.02221541,  0.16437879, -0.0732634 ,
#         0.2267682 , -0.00342179, -0.26462096,  0.01488896, -0.03751985,
#         0.13312222, -0.12063313, -0.11463998, -0.14151524, -0.12022159,
#         0.02096575,  0.10814608, -0.10239349,  0.08647764, -0.03939549,
#        -0.34820837, -0.02135331, -0.04295246,  0.0352081 , -0.13611796,
#         0.07716722,  0.1329015 , -0.10107249,  0.01696221,  0.01531519,
#         0.03622345,  0.02079487,  0.00127681,  0.21032894,  0.11868541,
#        -0.16340223,  0.07808898,  0.03038725,  0.37605044,  0.15308595,
#         0.01352182,  0.01740251, -0.00646839,  0.098926  , -0.23930059,
#         0.00496406,  0.20960271,  0.13559824,  0.05220539,  0.03601832,
#        -0.15099606, -0.02285625,  0.07757048, -0.25275436,  0.17586891,
#         0.06245376, -0.16760001, -0.07215512, -0.06074459,  0.1377632 ,
# ...

# %%
import cv2 as cv

cap = cv.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)
imageBackground = cv.imread('src/bg.jpg')
# Out:
# [ WARN:0@32.941] global cap_v4l.cpp:982 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@32.944] global obsensor_uvc_stream_channel.cpp:156 getStreamChannelGroup Camera index out of range

# %%
import os
folderModePath = "database"
modePathList = os.listdir(folderModePath)
imgModeList = []
for path in modePathList:
    imgModeList.append(cv.imread(os.path.join(folderModePath, path)))

# %%
import cv2 as cv
import face_recognition

cap = cv.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)
imageBackground = cv.imread('src/bg.jpg')

while True:
    
    ret, frame = cap.read()
    print(imageBackground)
    cv.imshow('frame', imageBackground)
    if cv.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv.destroyAllWindows()
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
# ...
